# %% [markdown]
# # Time series

# %%
import pandas as pd

# %%
names=['date', 'load', 'pv', 'grid']
data = pd.concat([pd.read_csv(os.path.join('data', x), names = names) for x in os.listdir('data') if x[0] != '.'])
data.index = range(0, len(data))
data.plot()

# %%
data['load'].plot(title='Pred transformáciou')

# %% [markdown]
# # Piecewise Aggregate Approximation

# %%
from tslearn.piecewise import PiecewiseAggregateApproximation

paa = PiecewiseAggregateApproximation(n_segments=10)
paa_data = paa.fit_transform(data['load'])

_, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(paa_data[0])
ax1.set_title('Transformované dáta')

ax2.plot(paa.inverse_transform(paa_data)[0])
ax2.set_title('Inverzná transformácia')
# Out:
# Text(0.5,1,'Inverzná transformácia')
